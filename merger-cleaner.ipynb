# %%
from datetime import date
import numpy as np
import pandas as pd



# load in raw csv
df = pd.read_csv('Merger-Data - 2021.csv')

# create columns indicating whether or not locations are inside or outside the US (city, state vs city, country)
df['loc_2_state_bool'] = df['firm_location_state_2'].isnull()
df['loc_1_state_bool'] = df['firm_location_state_1'].isnull()

final_firm_location_2 = []

# concatenate the locations for display
for index, row in df.iterrows():
    if row['loc_2_state_bool'] == False:
        final_locationa = row['firm_location_city_2'] + ', ' + row['firm_location_state_2']
        final_firm_location_2.append(final_locationa)
    else:
        final_locationb = row['firm_location_city_2'] + ', ' + row['firm_location_country_2']
        final_firm_location_2.append(final_locationb)
        
final_firm_location_1 = []

for index, row in df.iterrows():
    if row['loc_1_state_bool'] == False:
        final_locationa = row['firm_location_city_1'] + ', ' + row['firm_location_state_1']
        final_firm_location_1.append(final_locationa)
    else:
        final_locationb = row['firm_location_city_1'] + ', ' + row['firm_location_country_1']
        final_firm_location_1.append(final_locationb)
        
# add concatenated locations to dataframe
df['final_firm_location_2'] = final_firm_location_2
df['final_firm_location_1'] = final_firm_location_1
df['index1'] = df.index

# select final columns for display
final_df = df[['index1', 'link', 'report_date', 'firm_name_1', 'final_firm_location_1', 'firm_size_1', 'firm_name_2', 'final_firm_location_2', 'firm_size_2', 'merge_date']]

# export final csv
today = date.today()
final_df.to_csv('final_df-' + str(today) + '.csv', index=False)

# %%
from datetime import date

today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2021-08-27

# %%
df.head()
# Out:
#                                                 link report_date  \
# 0  https://www.law.com/ctlawtribune/2021/01/01/th...    01/01/21
# 1  https://www.law.com/americanlawyer/2021/01/04/...    01/04/21
# 2  https://www.law.com/newyorklawjournal/2021/01/...    01/05/21
# 3  https://www.law.com/newyorklawjournal/2021/01/...    01/05/21
# 4  https://www.law.com/newyorklawjournal/2021/01/...    01/05/21
#
#                  firm_name_1 firm_location_city_1 firm_location_state_1  \
# 0            Brody Wilkinson            Southport           Connecticut
# 1           Dinsmore & Shohl           Cincinnati                  Ohio
# 2  Milberg Phillips Grossman             New York              New York
# 3  Milberg Phillips Grossman             New York              New York
# 4  Milberg Phillips Grossman             New York              New York
#
#   firm_location_country_1  firm_size_1                firm_name_2  \
# 0           United States         21.0     Hermenze & Marcantonio
# 1           United States        656.0          Wooden McLaughlin
# 2           United States         20.0  Sanders Phillips Grossman
# 3           United States         20.0           Greg Coleman Law
# 4           United States         20.0           Whitfield Bryson
#
#   firm_location_city_2 firm_location_state_2  ... headline  article_text  \
# 0             Westport           Connecticut  ...      NaN           NaN
# 1         Indianapolis               Indiana  ...      NaN           NaN
# 2          Garden City              New York  ...      NaN           NaN
# 3            Knoxville             Tennessee  ...      NaN           NaN
# 4              Raleigh        North Carolina  ...      NaN           NaN
#
#   initial_source                                 alternate_source_1  \
# 0            NaN  https://plus.lexis.com/api/permalink/186e1ae0-...
# 1            NaN  https://plus.lexis.com/api/permalink/d3e1bab3-...
# 2            NaN  https://plus.lexis.com/api/permalink/972a370b-...
# 3            NaN  https://plus.lexis.com/api/permalink/972a370b-...
# 4            NaN  https://plus.lexis.com/api/permalink/972a370b-...
#
#   alternate_source_2 Unnamed: 18 loc_2_state_bool loc_1_state_bool  \
# 0                NaN         NaN            False            False
# 1                NaN         NaN            False            False
# 2                NaN         NaN            False            False
# 3                NaN         NaN            False            False
# 4                NaN         NaN            False            False
#
#      final_firm_location_2   final_firm_location_1
# 0    Westport, Connecticut  Southport, Connecticut
# 1    Indianapolis, Indiana        Cincinnati, Ohio
# 2    Garden City, New York      New York, New York
# 3     Knoxville, Tennessee      New York, New York
# 4  Raleigh, North Carolina      New York, New York
#
# [5 rows x 23 columns]

# %%
df['index1'] = df.index

# %%
df.head()
# Out:
#                                                 link report_date  \
# 0  https://www.law.com/ctlawtribune/2021/01/01/th...    01/01/21
# 1  https://www.law.com/americanlawyer/2021/01/04/...    01/04/21
# 2  https://www.law.com/newyorklawjournal/2021/01/...    01/05/21
# 3  https://www.law.com/newyorklawjournal/2021/01/...    01/05/21
# 4  https://www.law.com/newyorklawjournal/2021/01/...    01/05/21
#
#                  firm_name_1 firm_location_city_1 firm_location_state_1  \
# 0            Brody Wilkinson            Southport           Connecticut
# 1           Dinsmore & Shohl           Cincinnati                  Ohio
# 2  Milberg Phillips Grossman             New York              New York
# 3  Milberg Phillips Grossman             New York              New York
# 4  Milberg Phillips Grossman             New York              New York
#
#   firm_location_country_1  firm_size_1                firm_name_2  \
# 0           United States         21.0     Hermenze & Marcantonio
# 1           United States        656.0          Wooden McLaughlin
# 2           United States         20.0  Sanders Phillips Grossman
# 3           United States         20.0           Greg Coleman Law
# 4           United States         20.0           Whitfield Bryson
#
#   firm_location_city_2 firm_location_state_2  ... article_text  \
# 0             Westport           Connecticut  ...          NaN
# 1         Indianapolis               Indiana  ...          NaN
# 2          Garden City              New York  ...          NaN
# 3            Knoxville             Tennessee  ...          NaN
# 4              Raleigh        North Carolina  ...          NaN
#
#    initial_source                                 alternate_source_1  \
# 0             NaN  https://plus.lexis.com/api/permalink/186e1ae0-...
# 1             NaN  https://plus.lexis.com/api/permalink/d3e1bab3-...
# 2             NaN  https://plus.lexis.com/api/permalink/972a370b-...
# 3             NaN  https://plus.lexis.com/api/permalink/972a370b-...
# 4             NaN  https://plus.lexis.com/api/permalink/972a370b-...
#
#   alternate_source_2 Unnamed: 18 loc_2_state_bool loc_1_state_bool  \
# 0                NaN         NaN            False            False
# 1                NaN         NaN            False            False
# 2                NaN         NaN            False            False
# 3                NaN         NaN            False            False
# 4                NaN         NaN            False            False
#
#      final_firm_location_2   final_firm_location_1  index1
# 0    Westport, Connecticut  Southport, Connecticut       0
# 1    Indianapolis, Indiana        Cincinnati, Ohio       1
# 2    Garden City, New York      New York, New York       2
# 3     Knoxville, Tennessee      New York, New York       3
# 4  Raleigh, North Carolina      New York, New York       4
#
# [5 rows x 24 columns]

# %%
final_df = df[['link', 'report_date', 'firm_name_1', 'final_firm_location_1', 'firm_size_1', 'firm_name_2', 'final_firm_location_2', 'firm_size_2', 'merge_date']]

# %%
final_df.head()
# Out:
#                                                 link report_date  \
# 0  https://www.law.com/ctlawtribune/2021/01/01/th...    01/01/21
# 1  https://www.law.com/americanlawyer/2021/01/04/...    01/04/21
# 2  https://www.law.com/newyorklawjournal/2021/01/...    01/05/21
# 3  https://www.law.com/newyorklawjournal/2021/01/...    01/05/21
# 4  https://www.law.com/newyorklawjournal/2021/01/...    01/05/21
#
#                  firm_name_1   final_firm_location_1  firm_size_1  \
# 0            Brody Wilkinson  Southport, Connecticut         21.0
# 1           Dinsmore & Shohl        Cincinnati, Ohio        656.0
# 2  Milberg Phillips Grossman      New York, New York         20.0
# 3  Milberg Phillips Grossman      New York, New York         20.0
# 4  Milberg Phillips Grossman      New York, New York         20.0
#
#                  firm_name_2    final_firm_location_2  firm_size_2 merge_date
# 0     Hermenze & Marcantonio    Westport, Connecticut          3.0        NaN
# 1          Wooden McLaughlin    Indianapolis, Indiana         47.0        NaN
# 2  Sanders Phillips Grossman    Garden City, New York         40.0        NaN
# 3           Greg Coleman Law     Knoxville, Tennessee         12.0        NaN
# 4           Whitfield Bryson  Raleigh, North Carolina         15.0        NaN

# %%
final_firm_location_2 = []
for index, row in df.iterrows():
    if row['firm_location_state_2'].isnull() == True:
        final_locationa = row['firm_location_city_2'] + ', ' + row['firm_location_country_2']
        final_firm_location_1.append(final_locationa)
    else:
        final_locationb = row['firm_location_city_2'] + ', ' + row['firm_location_state_2']
        final_firm_location_1.append(final_locationb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11816/504640631.py in <module>
#       5         final_firm_location_1.append(final_locationa)
#       6     else:
# ----> 7         final_locationb = row['firm_location_city_2'] + ', ' + row['firm_location_state_2']
#       8         final_firm_location_1.append(final_locationb)
#
# TypeError: can only concatenate str (not "float") to str

# %%
final_firm_location_1 = []
for index, row in df.iterrows():
    if row['firm_location_state_1'].isnull():
        final_locationa = row['firm_location_city_1'] + ', ' + row['firm_location_country_1']
        final_firm_location_1.append(final_locationa)
    else:
        final_locationb = row['firm_location_city_1'] + ', ' + row['firm_location_state_1']
        final_firm_location_1.append(final_locationb)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11816/2314061297.py in <module>
#       1 final_firm_location_1 = []
#       2 for index, row in df.iterrows():
# ----> 3     if row['firm_location_state_1'].isnull():
#       4         final_locationa = row['firm_location_city_1'] + ', ' + row['firm_location_country_1']
#       5         final_firm_location_1.append(final_locationa)
#
# AttributeError: 'str' object has no attribute 'isnull'

# %%
len(final_firm_location)
# Out:
# 51

# %%
df['firm_location_state_2']
# Out:
# 0        Connecticut
# 1            Indiana
# 2           New York
# 3          Tennessee
# 4     North Carolina
# 5            Arizona
# 6            Indiana
# 7           Colorado
# 8               Ohio
# 9         California
# 10        California
# 11           Alabama
# 12               NaN
# 13          Illinois
# 14        California
# 15        New Jersey
# 16               NaN
# 17         Wisconsin
# 18           Florida
# 19               NaN
# 20          New York
# 21              Iowa
# 22               NaN
# 23          New York
# 24      Rhode Island
# 25              Ohio
# 26        California
# 27         Minnesota
# 28               NaN
# 29        New Jersey
# 30         Wisconsin
# 31               NaN
# 32           Florida
# 33           Georgia
# 34           Vermont
# 35        Washington
# 36           Florida
# 37               NaN
# 38          Delaware
# 39     Massachusetts
# 40          New York
# 41          Illinois
# 42             Texas
# 43    South Carolina
# 44               NaN
# 45     Massachusetts
# 46             Maine
# 47           Florida
# 48          Colorado
# 49          Kentucky
# 50        New Jersey
# Name: firm_location_state_2, dtype: object

# %%
final_firm_location_2 = []
for index, row in df.iterrows():
    if np.isnan(row['firm_location_state_2']):
        final_locationa = str(row['firm_location_city_2']) + ', ' + str(row['firm_location_country_2'])
        final_firm_location_2.append(final_locationa)
    else:
        final_locationb = str(row['firm_location_city_2']) + ', ' + str(row['firm_location_state_2'])
        final_firm_location_2.append(final_locationb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11816/1479299319.py in <module>
#       1 final_firm_location_2 = []
#       2 for index, row in df.iterrows():
# ----> 3     if np.isnan(row['firm_location_state_2']):
#       4         final_locationa = str(row['firm_location_city_2']) + ', ' + str(row['firm_location_country_2'])
#       5         final_firm_location_2.append(final_locationa)
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
np.isnan(value)

# %%
final_firm_location_2
# Out:
# ['Westport, Connecticut',
#  'Indianapolis, Indiana',
#  'Garden City, New York',
#  'Knoxville, Tennessee',
#  'Raleigh, North Carolina',
#  'Yuma, Arizona',
#  'Indianapolis, Indiana',
#  'Denver, Colorado',
#  'Cleveland, Ohio',
#  'Pasadena, California',
#  'Pasadena, California',
#  'Birmingham, Alabama',
#  'London, nan',
#  'Chicago, Illinois',
#  'Los Angeles, California',
#  'Red Bank, New Jersey',
#  'Barranquilla, nan',
#  'Appleton, Wisconsin',
#  'Boca Raton, Florida',
#  'Quito, nan',
#  'New York, New York',
#  'Spirit Lake, Iowa',
#  'La Paz, nan',
#  'New York, New York',
#  'Providence, Rhode Island',
#  'Independence, Ohio',
#  'Sherman Oaks, California',
#  'Long Prairie, Minnesota',
#  'Lagos, nan',
#  'Woodland Park, New Jersey',
#  'Green Bay, Wisconsin',
#  'Caracas, nan',
#  'St. Petersburg, Florida',
#  'Atlanta, Georgia',
#  'Hartford, Vermont',
#  'Seattle, Washington',
#  'Palm Beach, Florida',
#  'Genoa, nan',
#  'Hockessin, Delaware',
#  'Wellesley, Massachusetts',
#  'New York, New York',
#  'Chicago, Illinois',
#  'Dallas, Texas',
#  'Charleston, South Carolina',
#  'Luxembourg City, nan',
#  'Boston, Massachusetts',
#  'Portland, Maine',
#  'St. Petersburg, Florida',
#  'Denver, Colorado',
#  'Covington, Kentucky',
#  'Tinton Falls, New Jersey']

# %%
f = lambda row: row['final_firm_location_1'] if (str(row['firm_location_state_1'])=='nan') else row['B']

# %%
final_location_1 = []
for index, row in df.iterrows():
    if

# %%
for item, frame in df.iteritems():
    if pd.notnull(frame):
        print frame

# %%
for index, row in df.iterrows():
    if ['firm_location_state_1'].isnull:
        df["final_firm_location_1"] = str(df['firm_location_country_1'] + ', ' + df['firm_location_city_1'])
    else:
        df['final_firm_location_1'] = str(df['firm_location_city_1'] + ', ' + df['firm_location_state_1'])

# %%
df['final_firm_location_1']
# Out:
# 0     0             United States, Southport\n1     ...
# 1     0             United States, Southport\n1     ...
# 2     0             United States, Southport\n1     ...
# 3     0             United States, Southport\n1     ...
# 4     0             United States, Southport\n1     ...
# 5     0             United States, Southport\n1     ...
# 6     0             United States, Southport\n1     ...
# 7     0             United States, Southport\n1     ...
# 8     0             United States, Southport\n1     ...
# 9     0             United States, Southport\n1     ...
# 10    0             United States, Southport\n1     ...
# 11    0             United States, Southport\n1     ...
# 12    0             United States, Southport\n1     ...
# 13    0             United States, Southport\n1     ...
# 14    0             United States, Southport\n1     ...
# 15    0             United States, Southport\n1     ...
# 16    0             United States, Southport\n1     ...
# 17    0             United States, Southport\n1     ...
# 18    0             United States, Southport\n1     ...
# 19    0             United States, Southport\n1     ...
# 20    0             United States, Southport\n1     ...
# 21    0             United States, Southport\n1     ...
# 22    0             United States, Southport\n1     ...
# 23    0             United States, Southport\n1     ...
# 24    0             United States, Southport\n1     ...
# 25    0             United States, Southport\n1     ...
# 26    0             United States, Southport\n1     ...
# 27    0             United States, Southport\n1     ...
# 28    0             United States, Southport\n1     ...
# 29    0             United States, Southport\n1     ...
# 30    0             United States, Southport\n1     ...
# 31    0             United States, Southport\n1     ...
# 32    0             United States, Southport\n1     ...
# 33    0             United States, Southport\n1     ...
# 34    0             United States, Southport\n1     ...
# 35    0             United States, Southport\n1     ...
# 36    0             United States, Southport\n1     ...
# 37    0             United States, Southport\n1     ...
# 38    0             United States, Southport\n1     ...
# 39    0             United States, Southport\n1     ...
# 40    0             United States, Southport\n1     ...
# 41    0             United States, Southport\n1     ...
# 42    0             United States, Southport\n1     ...
# 43    0             United States, Southport\n1     ...
# 44    0             United States, Southport\n1     ...
# 45    0             United States, Southport\n1     ...
# 46    0             United States, Southport\n1     ...
# 47    0             United States, Southport\n1     ...
# 48    0             United States, Southport\n1     ...
# 49    0             United States, Southport\n1     ...
# 50    0             United States, Southport\n1     ...
# Name: final_firm_location_1, dtype: object

# %%
for index, row in df.iterrows():
    if firm_location_state_1 == NaN

# %%
df['final_firm_location_1'] = []
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11816/646310532.py in <module>
# ----> 1 df['final_firm_location_1'] = []
#
# c:\users\bells4\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3605         else:
#    3606             # set column
# -> 3607             self._set_item(key, value)
#    3608
#    3609     def _setitem_slice(self, key: slice, value):
#
# c:\users\bells4\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3777         ensure homogeneity.
#    3778         """
# -> 3779         value = self._sanitize_column(value)
#    3780
#    3781         if (
#
# c:\users\bells4\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4502
#    4503         if is_list_like(value):
# -> 4504             com.require_length_match(value, self.index)
#    4505         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4506
#
# c:\users\bells4\appdata\local\programs\python\python39\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (0) does not match length of index (51)

# %%
f = lambda row: row['firm_location_city'] if (row['B'].isnull()) else row['B']
df['B'] = df.apply(f, axis=1)

# %%
final_df = df[['link', 'report_date', 'firm_name_1', 'firm_location']]
